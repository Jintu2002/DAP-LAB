# %%
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
plots = pd.read_csv("sales-of-shampoo-over-a-three-ye.csv")
plots
# Out:
#     Month  Sales of shampoo over a three year period
# 0   1-Jan                                      266.0
# 1   1-Feb                                      145.9
# 2   1-Mar                                      183.1
# 3   1-Apr                                      119.3
# 4   1-May                                      180.3
# 5   1-Jun                                      168.5
# 6   1-Jul                                      231.8
# 7   1-Aug                                      224.5
# 8   1-Sep                                      192.8
# 9   1-Oct                                      122.9
# 10  1-Nov                                      336.5
# 11  1-Dec                                      185.9
# 12  2-Jan                                      194.3
# 13  2-Feb                                      149.5
# 14  2-Mar                                      210.1
# 15  2-Apr                                      273.3
# 16  2-May                                      191.4
# ...

# %%
x = []
y =[]

plots = pd.read_csv("sales-of-shampoo-over-a-three-ye.csv")
plt.hist(plots['Sales of shampoo over a three year period'], bins=30, color="black", edgecolor="white", alpha=0.7, label='sales')
plt.xlabel('month')
plt.ylabel("sales")
plt.title("total sale")
plt.legend()
plt.show()
